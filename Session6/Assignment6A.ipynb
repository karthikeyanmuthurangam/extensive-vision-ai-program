100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2684 - acc: 0.9162 - val_loss: 0.6183 - val_acc: 0.8295
# Epoch 93/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2536 - acc: 0.9203 - val_loss: 0.6115 - val_acc: 0.8302
# Epoch 94/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2556 - acc: 0.9197 - val_loss: 0.6333 - val_acc: 0.8321
# Epoch 95/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2594 - acc: 0.9178 - val_loss: 0.6225 - val_acc: 0.8254
# Epoch 96/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2483 - acc: 0.9215 - val_loss: 0.6480 - val_acc: 0.8256
# Epoch 97/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2478 - acc: 0.9232 - val_loss: 0.6071 - val_acc: 0.8281
# Epoch 98/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2584 - acc: 0.9190 - val_loss: 0.6543 - val_acc: 0.8267
# Epoch 99/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2407 - acc: 0.9249 - val_loss: 0.6490 - val_acc: 0.8272
# Epoch 100/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2379 - acc: 0.9257 - val_loss: 0.6892 - val_acc: 0.8282
# Model took 891.39 seconds to train
# Accuracy on test data is: 82.82

# %%
# Define the model
model = Sequential()

model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3))) #32 RF-3x3
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))


model.add(Convolution2D(48, 3, 3)) #30 RF-5x5
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))


model.add(MaxPooling2D(pool_size=(2, 2))) #15 RF-10x10

model.add(Convolution2D(96, 3, 3, border_mode='same')) #15 #RF-12x12
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))


model.add(Convolution2D(96, 3, 3)) #13 RF-14x14
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))


model.add(MaxPooling2D(pool_size=(2, 2))) #6 RF-28x28
model.add(Convolution2D(48, 1, 1)) #6 RF-17x17

model.add(Convolution2D(192, 3, 3, border_mode='same')) #6 RF-30x30
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))


model.add(Convolution2D(192, 3, 3)) #4 RF-32x32
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(MaxPooling2D(pool_size=(2, 2))) #2
model.add(Convolution2D(96, 1, 1))


model.add(Convolution2D(192, 2, 2)) #1
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Convolution2D(10, 1, 1)) #1
model.add(Activation('relu'))

model.add(Flatten())
model.add(Activation('softmax'))

learning_rate = 0.005

def scheduler(epoch, lr):
  return round(learning_rate * 1/(1 + 0.35 * epoch), 10)

mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)


# Compile the model
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (2, 2))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:51: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_10 (Activation)   (None, 32, 32, 48)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 48)        192
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_11 (Activation)   (None, 30, 30, 48)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 30, 30, 48)        192
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_12 (Activation)   (None, 15, 15, 96)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 15, 15, 96)        384
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_13 (Activation)   (None, 13, 13, 96)        0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 13, 13, 96)        384
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 6, 6, 48)          4656
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 6, 6, 192)         83136
# _________________________________________________________________
# activation_14 (Activation)   (None, 6, 6, 192)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 6, 6, 192)         768
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_15 (Activation)   (None, 4, 4, 192)         0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 4, 4, 192)         768
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 192)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 2, 2, 96)          18528
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 1, 1, 192)         73920
# _________________________________________________________________
# activation_16 (Activation)   (None, 1, 1, 192)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 1, 1, 192)         768
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 1, 1, 10)          1930
# _________________________________________________________________
# activation_17 (Activation)   (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_18 (Activation)   (None, 10)                0
# =================================================================
# Total params: 664,330
# Trainable params: 662,602
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels),
                                 callbacks=[mc], verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=100)`
#   del sys.path[0]
# W0618 16:32:32.284895 139950232385408 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 390/390 [==============================] - 20s 51ms/step - loss: 1.4871 - acc: 0.4704 - val_loss: 1.7262 - val_acc: 0.4429
#
# Epoch 00001: val_acc improved from -inf to 0.44290, saving model to best_model.h5
# Epoch 2/100
# 390/390 [==============================] - 16s 41ms/step - loss: 1.0116 - acc: 0.6465 - val_loss: 1.1822 - val_acc: 0.5993
#
# Epoch 00002: val_acc improved from 0.44290 to 0.59930, saving model to best_model.h5
# Epoch 3/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.8139 - acc: 0.7144 - val_loss: 0.8665 - val_acc: 0.7089
#
# Epoch 00003: val_acc improved from 0.59930 to 0.70890, saving model to best_model.h5
# Epoch 4/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.7092 - acc: 0.7520 - val_loss: 0.8138 - val_acc: 0.7176
#
# Epoch 00004: val_acc improved from 0.70890 to 0.71760, saving model to best_model.h5
# Epoch 5/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6382 - acc: 0.7772 - val_loss: 0.7729 - val_acc: 0.7283
#
# Epoch 00005: val_acc improved from 0.71760 to 0.72830, saving model to best_model.h5
# Epoch 6/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5800 - acc: 0.7981 - val_loss: 0.8025 - val_acc: 0.7215
#
# Epoch 00006: val_acc did not improve from 0.72830
# Epoch 7/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5390 - acc: 0.8110 - val_loss: 0.8500 - val_acc: 0.7185
#
# Epoch 00007: val_acc did not improve from 0.72830
# Epoch 8/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5002 - acc: 0.8255 - val_loss: 0.8532 - val_acc: 0.7362
#
# Epoch 00008: val_acc improved from 0.72830 to 0.73620, saving model to best_model.h5
# Epoch 9/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.4712 - acc: 0.8361 - val_loss: 0.7344 - val_acc: 0.7590
#
# Epoch 00009: val_acc improved from 0.73620 to 0.75900, saving model to best_model.h5
# Epoch 10/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.4451 - acc: 0.8458 - val_loss: 0.6391 - val_acc: 0.7806
#
# Epoch 00010: val_acc improved from 0.75900 to 0.78060, saving model to best_model.h5
# Epoch 11/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.4233 - acc: 0.8512 - val_loss: 0.6006 - val_acc: 0.8027
#
# Epoch 00011: val_acc improved from 0.78060 to 0.80270, saving model to best_model.h5
# Epoch 12/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.3943 - acc: 0.8610 - val_loss: 0.6449 - val_acc: 0.7897
#
# Epoch 00012: val_acc did not improve from 0.80270
# Epoch 13/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.3752 - acc: 0.8672 - val_loss: 0.6657 - val_acc: 0.7916
#
# Epoch 00013: val_acc did not improve from 0.80270
# Epoch 14/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.3620 - acc: 0.8708 - val_loss: 0.5866 - val_acc: 0.8068
#
# Epoch 00014: val_acc improved from 0.80270 to 0.80680, saving model to best_model.h5
# Epoch 15/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.3443 - acc: 0.8776 - val_loss: 0.5756 - val_acc: 0.8194
#
# Epoch 00015: val_acc improved from 0.80680 to 0.81940, saving model to best_model.h5
# Epoch 16/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.3302 - acc: 0.8831 - val_loss: 0.5822 - val_acc: 0.8083
#
# Epoch 00016: val_acc did not improve from 0.81940
# Epoch 17/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.3115 - acc: 0.8895 - val_loss: 0.6723 - val_acc: 0.7881
#
# Epoch 00017: val_acc did not improve from 0.81940
# Epoch 18/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.3025 - acc: 0.8931 - val_loss: 0.5556 - val_acc: 0.8233
#
# Epoch 00018: val_acc improved from 0.81940 to 0.82330, saving model to best_model.h5
# Epoch 19/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.2871 - acc: 0.8984 - val_loss: 0.6743 - val_acc: 0.7894
#
# Epoch 00019: val_acc did not improve from 0.82330
# Epoch 20/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.2786 - acc: 0.9013 - val_loss: 0.5796 - val_acc: 0.8136
#
# Epoch 00020: val_acc did not improve from 0.82330
# Epoch 21/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.2685 - acc: 0.9054 - val_loss: 0.5927 - val_acc: 0.8136
#
# Epoch 00021: val_acc did not improve from 0.82330
# Epoch 22/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.2634 - acc: 0.9066 - val_loss: 0.5771 - val_acc: 0.8231
#
# Epoch 00022: val_acc did not improve from 0.82330
# Epoch 23/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.2491 - acc: 0.9115 - val_loss: 0.6959 - val_acc: 0.7888
#
# Epoch 00023: val_acc did not improve from 0.82330
# Epoch 24/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.2395 - acc: 0.9140 - val_loss: 0.5470 - val_acc: 0.8282
#
# Epoch 00024: val_acc improved from 0.82330 to 0.82820, saving model to best_model.h5
# Epoch 25/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.2401 - acc: 0.9150 - val_loss: 0.5165 - val_acc: 0.8399
#
# Epoch 00025: val_acc improved from 0.82820 to 0.83990, saving model to best_model.h5
# Epoch 26/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.2268 - acc: 0.9182 - val_loss: 0.5385 - val_acc: 0.8331
#
# Epoch 00026: val_acc did not improve from 0.83990
# Epoch 27/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.2253 - acc: 0.9196 - val_loss: 0.5954 - val_acc: 0.8203
#
# Epoch 00027: val_acc did not improve from 0.83990
# Epoch 28/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.2136 - acc: 0.9235 - val_loss: 0.6254 - val_acc: 0.8172
#
# Epoch 00028: val_acc did not improve from 0.83990
# Epoch 29/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.2084 - acc: 0.9252 - val_loss: 0.6330 - val_acc: 0.8148
#
# Epoch 00029: val_acc did not improve from 0.83990
# Epoch 30/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.2031 - acc: 0.9271 - val_loss: 0.6269 - val_acc: 0.8146
#
# Epoch 00030: val_acc did not improve from 0.83990
# Epoch 31/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.2019 - acc: 0.9284 - val_loss: 0.6124 - val_acc: 0.8170
#
# Epoch 00031: val_acc did not improve from 0.83990
# Epoch 32/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1922 - acc: 0.9320 - val_loss: 0.5716 - val_acc: 0.8277
#
# Epoch 00032: val_acc did not improve from 0.83990
# Epoch 33/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1924 - acc: 0.9307 - val_loss: 0.5506 - val_acc: 0.8370
#
# Epoch 00033: val_acc did not improve from 0.83990
# Epoch 34/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1842 - acc: 0.9330 - val_loss: 0.5957 - val_acc: 0.8244
#
# Epoch 00034: val_acc did not improve from 0.83990
# Epoch 35/100
# 390/390 [==============================] - 16s 40ms/step - loss: 0.1755 - acc: 0.9354 - val_loss: 0.6368 - val_acc: 0.8178
#
# Epoch 00035: val_acc did not improve from 0.83990
# Epoch 36/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1750 - acc: 0.9377 - val_loss: 0.5653 - val_acc: 0.8358
#
# Epoch 00036: val_acc did not improve from 0.83990
# Epoch 37/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1696 - acc: 0.9384 - val_loss: 0.5544 - val_acc: 0.8329
#
# Epoch 00037: val_acc did not improve from 0.83990
# Epoch 38/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1697 - acc: 0.9392 - val_loss: 0.5379 - val_acc: 0.8419
#
# Epoch 00038: val_acc improved from 0.83990 to 0.84190, saving model to best_model.h5
# Epoch 39/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1637 - acc: 0.9420 - val_loss: 0.5251 - val_acc: 0.8454
#
# Epoch 00039: val_acc improved from 0.84190 to 0.84540, saving model to best_model.h5
# Epoch 40/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1608 - acc: 0.9422 - val_loss: 0.5772 - val_acc: 0.8328
#
# Epoch 00040: val_acc did not improve from 0.84540
# Epoch 41/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1600 - acc: 0.9417 - val_loss: 0.5779 - val_acc: 0.8298
#
# Epoch 00041: val_acc did not improve from 0.84540
# Epoch 42/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1549 - acc: 0.9442 - val_loss: 0.4987 - val_acc: 0.8498
#
# Epoch 00042: val_acc improved from 0.84540 to 0.84980, saving model to best_model.h5
# Epoch 43/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1456 - acc: 0.9467 - val_loss: 0.5794 - val_acc: 0.8325
#
# Epoch 00043: val_acc did not improve from 0.84980
# Epoch 44/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1533 - acc: 0.9446 - val_loss: 0.5558 - val_acc: 0.8393
#
# Epoch 00044: val_acc did not improve from 0.84980
# Epoch 45/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1422 - acc: 0.9487 - val_loss: 0.5131 - val_acc: 0.8505
#
# Epoch 00045: val_acc improved from 0.84980 to 0.85050, saving model to best_model.h5
# Epoch 46/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1407 - acc: 0.9502 - val_loss: 0.5872 - val_acc: 0.8364
#
# Epoch 00046: val_acc did not improve from 0.85050
# Epoch 47/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1428 - acc: 0.9490 - val_loss: 0.6026 - val_acc: 0.8269
#
# Epoch 00047: val_acc did not improve from 0.85050
# Epoch 48/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1395 - acc: 0.9495 - val_loss: 0.5680 - val_acc: 0.8367
#
# Epoch 00048: val_acc did not improve from 0.85050
# Epoch 49/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1398 - acc: 0.9497 - val_loss: 0.6325 - val_acc: 0.8243
#
# Epoch 00049: val_acc did not improve from 0.85050
# Epoch 50/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1402 - acc: 0.9506 - val_loss: 0.5318 - val_acc: 0.8441
#
# Epoch 00050: val_acc did not improve from 0.85050
# Epoch 51/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1335 - acc: 0.9529 - val_loss: 0.5573 - val_acc: 0.8368
#
# Epoch 00051: val_acc did not improve from 0.85050
# Epoch 52/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1308 - acc: 0.9521 - val_loss: 0.6118 - val_acc: 0.8313
#
# Epoch 00052: val_acc did not improve from 0.85050
# Epoch 53/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1275 - acc: 0.9546 - val_loss: 0.5946 - val_acc: 0.8331
#
# Epoch 00053: val_acc did not improve from 0.85050
# Epoch 54/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1261 - acc: 0.9546 - val_loss: 0.5591 - val_acc: 0.8450
#
# Epoch 00054: val_acc did not improve from 0.85050
# Epoch 55/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1266 - acc: 0.9548 - val_loss: 0.5079 - val_acc: 0.8563
#
# Epoch 00055: val_acc improved from 0.85050 to 0.85630, saving model to best_model.h5
# Epoch 56/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1245 - acc: 0.9556 - val_loss: 0.6003 - val_acc: 0.8373
#
# Epoch 00056: val_acc did not improve from 0.85630
# Epoch 57/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1240 - acc: 0.9563 - val_loss: 0.5254 - val_acc: 0.8515
#
# Epoch 00057: val_acc did not improve from 0.85630
# Epoch 58/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1197 - acc: 0.9572 - val_loss: 0.5671 - val_acc: 0.8445
#
# Epoch 00058: val_acc did not improve from 0.85630
# Epoch 59/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1250 - acc: 0.9556 - val_loss: 0.5826 - val_acc: 0.8383
#
# Epoch 00059: val_acc did not improve from 0.85630
# Epoch 60/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1155 - acc: 0.9589 - val_loss: 0.5657 - val_acc: 0.8445
#
# Epoch 00060: val_acc did not improve from 0.85630
# Epoch 61/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1160 - acc: 0.9594 - val_loss: 0.5245 - val_acc: 0.8524
#
# Epoch 00061: val_acc did not improve from 0.85630
# Epoch 62/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1131 - acc: 0.9600 - val_loss: 0.5662 - val_acc: 0.8415
#
# Epoch 00062: val_acc did not improve from 0.85630
# Epoch 63/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1119 - acc: 0.9594 - val_loss: 0.5573 - val_acc: 0.8495
#
# Epoch 00063: val_acc did not improve from 0.85630
# Epoch 64/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1079 - acc: 0.9611 - val_loss: 0.5475 - val_acc: 0.8486
#
# Epoch 00064: val_acc did not improve from 0.85630
# Epoch 65/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1123 - acc: 0.9602 - val_loss: 0.5564 - val_acc: 0.8486
#
# Epoch 00065: val_acc did not improve from 0.85630
# Epoch 66/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.1077 - acc: 0.9613 - val_loss: 0.5427 - val_acc: 0.8491
#
# Epoch 00066: val_acc did not improve from 0.85630
# Epoch 67/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1071 - acc: 0.9608 - val_loss: 0.6268 - val_acc: 0.8356
#
# Epoch 00067: val_acc did not improve from 0.85630
# Epoch 68/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1082 - acc: 0.9616 - val_loss: 0.5906 - val_acc: 0.8411
#
# Epoch 00068: val_acc did not improve from 0.85630
# Epoch 69/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1061 - acc: 0.9618 - val_loss: 0.5626 - val_acc: 0.8464
#
# Epoch 00069: val_acc did not improve from 0.85630
# Epoch 70/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1049 - acc: 0.9625 - val_loss: 0.6183 - val_acc: 0.8371
#
# Epoch 00070: val_acc did not improve from 0.85630
# Epoch 71/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1041 - acc: 0.9631 - val_loss: 0.5571 - val_acc: 0.8503
#
# Epoch 00071: val_acc did not improve from 0.85630
# Epoch 72/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1022 - acc: 0.9634 - val_loss: 0.5312 - val_acc: 0.8575
#
# Epoch 00072: val_acc improved from 0.85630 to 0.85750, saving model to best_model.h5
# Epoch 73/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1017 - acc: 0.9630 - val_loss: 0.6259 - val_acc: 0.8374
#
# Epoch 00073: val_acc did not improve from 0.85750
# Epoch 74/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0961 - acc: 0.9653 - val_loss: 0.5252 - val_acc: 0.8582
#
# Epoch 00074: val_acc improved from 0.85750 to 0.85820, saving model to best_model.h5
# Epoch 75/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0987 - acc: 0.9648 - val_loss: 0.5687 - val_acc: 0.8473
#
# Epoch 00075: val_acc did not improve from 0.85820
# Epoch 76/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.1002 - acc: 0.9640 - val_loss: 0.5618 - val_acc: 0.8491
#
# Epoch 00076: val_acc did not improve from 0.85820
# Epoch 77/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0937 - acc: 0.9674 - val_loss: 0.6177 - val_acc: 0.8371
#
# Epoch 00077: val_acc did not improve from 0.85820
# Epoch 78/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0949 - acc: 0.9656 - val_loss: 0.6175 - val_acc: 0.8338
#
# Epoch 00078: val_acc did not improve from 0.85820
# Epoch 79/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0915 - acc: 0.9676 - val_loss: 0.5472 - val_acc: 0.8529
#
# Epoch 00079: val_acc did not improve from 0.85820
# Epoch 80/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0941 - acc: 0.9668 - val_loss: 0.5988 - val_acc: 0.8482
#
# Epoch 00080: val_acc did not improve from 0.85820
# Epoch 81/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0935 - acc: 0.9661 - val_loss: 0.5627 - val_acc: 0.8516
#
# Epoch 00081: val_acc did not improve from 0.85820
# Epoch 82/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0932 - acc: 0.9668 - val_loss: 0.5535 - val_acc: 0.8534
#
# Epoch 00082: val_acc did not improve from 0.85820
# Epoch 83/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0918 - acc: 0.9675 - val_loss: 0.5751 - val_acc: 0.8467
#
# Epoch 00083: val_acc did not improve from 0.85820
# Epoch 84/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0925 - acc: 0.9662 - val_loss: 0.5288 - val_acc: 0.8562
#
# Epoch 00084: val_acc did not improve from 0.85820
# Epoch 85/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0889 - acc: 0.9679 - val_loss: 0.6119 - val_acc: 0.8453
#
# Epoch 00085: val_acc did not improve from 0.85820
# Epoch 86/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0891 - acc: 0.9680 - val_loss: 0.5639 - val_acc: 0.8509
#
# Epoch 00086: val_acc did not improve from 0.85820
# Epoch 87/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0904 - acc: 0.9669 - val_loss: 0.5847 - val_acc: 0.8480
#
# Epoch 00087: val_acc did not improve from 0.85820
# Epoch 88/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0862 - acc: 0.9694 - val_loss: 0.6300 - val_acc: 0.8409
#
# Epoch 00088: val_acc did not improve from 0.85820
# Epoch 89/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0890 - acc: 0.9682 - val_loss: 0.6051 - val_acc: 0.8451
#
# Epoch 00089: val_acc did not improve from 0.85820
# Epoch 90/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0790 - acc: 0.9726 - val_loss: 0.5635 - val_acc: 0.8543
#
# Epoch 00090: val_acc did not improve from 0.85820
# Epoch 91/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0883 - acc: 0.9694 - val_loss: 0.5825 - val_acc: 0.8472
#
# Epoch 00091: val_acc did not improve from 0.85820
# Epoch 92/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0872 - acc: 0.9691 - val_loss: 0.6137 - val_acc: 0.8500
#
# Epoch 00092: val_acc did not improve from 0.85820
# Epoch 93/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0841 - acc: 0.9701 - val_loss: 0.5908 - val_acc: 0.8470
#
# Epoch 00093: val_acc did not improve from 0.85820
# Epoch 94/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0841 - acc: 0.9691 - val_loss: 0.5363 - val_acc: 0.8597
#
# Epoch 00094: val_acc improved from 0.85820 to 0.85970, saving model to best_model.h5
# Epoch 95/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0770 - acc: 0.9722 - val_loss: 0.5826 - val_acc: 0.8478
#
# Epoch 00095: val_acc did not improve from 0.85970
# Epoch 96/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.0782 - acc: 0.9719 - val_loss: 0.6494 - val_acc: 0.8321
#
# Epoch 00096: val_acc did not improve from 0.85970
# Epoch 97/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.0794 - acc: 0.9717 - val_loss: 0.5709 - val_acc: 0.8555
#
# Epoch 00097: val_acc did not improve from 0.85970
# Epoch 98/100
# 390/390 [==============================] - 15s 39ms/step - loss: 0.0809 - acc: 0.9717 - val_loss: 0.5517 - val_acc: 0.8619
#
# Epoch 00098: val_acc improved from 0.85970 to 0.86190, saving model to best_model.h5
# Epoch 99/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.0800 - acc: 0.9712 - val_loss: 0.5715 - val_acc: 0.8527
#
# Epoch 00099: val_acc did not improve from 0.86190
# Epoch 100/100
# 390/390 [==============================] - 15s 40ms/step - loss: 0.0782 - acc: 0.9720 - val_loss: 0.5972 - val_acc: 0.8507
#
# Epoch 00100: val_acc did not improve from 0.86190
# Model took 1551.22 seconds to train
# Accuracy on test data is: 85.07
